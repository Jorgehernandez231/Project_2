# %%
import pandas as pd

# %%
dt = pd.read_csv('happiness_all_years_clean.csv')
country_id = pd.read_csv('country_id.csv')
dt
# Out:
#                       country  year              region  score  \
# 0                 Switzerland  2015      Western Europe  7.587
# 1                     Iceland  2015      Western Europe  7.561
# 2                     Denmark  2015      Western Europe  7.527
# 3                      Norway  2015      Western Europe  7.522
# 4                      Canada  2015       North America  7.427
# ..                        ...   ...                 ...    ...
# 777                    Rwanda  2019  Sub-Saharan Africa  3.334
# 778                  Tanzania  2019  Sub-Saharan Africa  3.231
# 779               Afghanistan  2019       Southern Asia  3.203
# 780  Central African Republic  2019  Sub-Saharan Africa  3.083
# 781               South Sudan  2019  Sub-Saharan Africa  2.853
#
#      gdp_per_capita  social_support  healthy_life_expectancy  freedom  \
# 0           1.39651         1.34951                  0.94143  0.66557
# ...

# %%
country_id
# Out:
#      country_id  region_id                  country
# 0             1          1              Switzerland
# 1             2          1                  Iceland
# 2             3          1                  Denmark
# 3             4          1                   Norway
# 4             5          2                   Canada
# ..          ...        ...                      ...
# 165         166          8  Hong Kong S.A.R., China
# 166         167          5        Trinidad & Tobago
# 167         168         11          Northern Cyprus
# 168         169          7          North Macedonia
# 169         170          9                   Gambia
#
# [170 rows x 3 columns]

# %%
dt1 = pd.merge(
    dt,
    country_id[['country', 'country_id']],
    on='country',
    how='left'
)

# %%
dt1
# Out:
#                       country  year              region  score  \
# 0                 Switzerland  2015      Western Europe  7.587
# 1                     Iceland  2015      Western Europe  7.561
# 2                     Denmark  2015      Western Europe  7.527
# 3                      Norway  2015      Western Europe  7.522
# 4                      Canada  2015       North America  7.427
# ..                        ...   ...                 ...    ...
# 777                    Rwanda  2019  Sub-Saharan Africa  3.334
# 778                  Tanzania  2019  Sub-Saharan Africa  3.231
# 779               Afghanistan  2019       Southern Asia  3.203
# 780  Central African Republic  2019  Sub-Saharan Africa  3.083
# 781               South Sudan  2019  Sub-Saharan Africa  2.853
#
#      gdp_per_capita  social_support  healthy_life_expectancy  freedom  \
# 0           1.39651         1.34951                  0.94143  0.66557
# ...

# %%
dt1 = dt1.drop(columns=['country'])
dt1
# Out:
#      year              region  score  gdp_per_capita  social_support  \
# 0    2015      Western Europe  7.587         1.39651         1.34951
# 1    2015      Western Europe  7.561         1.30232         1.40223
# 2    2015      Western Europe  7.527         1.32548         1.36058
# 3    2015      Western Europe  7.522         1.45900         1.33095
# 4    2015       North America  7.427         1.32629         1.32261
# ..    ...                 ...    ...             ...             ...
# 777  2019  Sub-Saharan Africa  3.334         0.35900         0.71100
# 778  2019  Sub-Saharan Africa  3.231         0.47600         0.88500
# 779  2019       Southern Asia  3.203         0.35000         0.51700
# 780  2019  Sub-Saharan Africa  3.083         0.02600         0.00000
# 781  2019  Sub-Saharan Africa  2.853         0.30600         0.57500
#
#      healthy_life_expectancy  freedom  generosity  corruption  country_id
# ...

# %%
dt1 = dt1.drop(columns=['region'])

# %%
col = ['country_id','year', 'score', 'gdp_per_capita', 'social_support','healthy_life_expectancy', 'freedom', 'generosity', 'corruption']

dt1 = dt1[col]
dt1
# Out:
#      country_id  year  score  gdp_per_capita  social_support  \
# 0             1  2015  7.587         1.39651         1.34951
# 1             2  2015  7.561         1.30232         1.40223
# 2             3  2015  7.527         1.32548         1.36058
# 3             4  2015  7.522         1.45900         1.33095
# 4             5  2015  7.427         1.32629         1.32261
# ..          ...   ...    ...             ...             ...
# 777         154  2019  3.334         0.35900         0.71100
# 778         146  2019  3.231         0.47600         0.88500
# 779         153  2019  3.203         0.35000         0.51700
# 780         148  2019  3.083         0.02600         0.00000
# 781         164  2019  2.853         0.30600         0.57500
#
#      healthy_life_expectancy  freedom  generosity  corruption
# 0                    0.94143  0.66557     0.29678     0.41978
# 1                    0.94784  0.62877     0.43630     0.14145
# ...

# %%
country_id
# Out:
#      country_id  region_id                  country
# 0             1          1              Switzerland
# 1             2          1                  Iceland
# 2             3          1                  Denmark
# 3             4          1                   Norway
# 4             5          2                   Canada
# ..          ...        ...                      ...
# 165         166          8  Hong Kong S.A.R., China
# 166         167          5        Trinidad & Tobago
# 167         168         11          Northern Cyprus
# 168         169          7          North Macedonia
# 169         170          9                   Gambia
#
# [170 rows x 3 columns]

# %%
#country_id = pd.merge(
    country_id,
    dt1[['country_id','gdp_per_capita', 'corruption']],
    on='country_id',
    how='left'
    
)
country_id
# Out:
#   Cell In[31], line 2
#     country_id,
#     ^
# IndentationError: unexpected indent

# %%
df_2015 = dt1[dt1['year'] == 2015]
df_2016 = dt1[dt1['year'] == 2016]
df_2017 = dt1[dt1['year'] == 2017]
df_2018 = dt1[dt1['year'] == 2018]
df_2019 = dt1[dt1['year'] == 2019]

# %%
df_2015.to_csv('df_2015.csv',index=False)
df_2016.to_csv('df_2016.csv',index=False)
df_2017.to_csv('df_2017.csv',index=False)
df_2018.to_csv('df_2018.csv',index=False)
df_2019.to_csv('df_2019.csv',index=False)
