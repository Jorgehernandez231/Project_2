# %%
import pandas as pd

# %%
dt_1 = pd.read_csv("F:/Descargas/2015.csv")
dt_2 = pd.read_csv("F:/Descargas/2016.csv")
dt_3 = pd.read_csv("F:/Descargas/2017.csv")
dt_4 = pd.read_csv("F:/Descargas/2018.csv")
dt_5 = pd.read_csv("F:/Descargas/2019.csv")

# %%
dt_1.to_csv('data_2015.csv')
dt_2.to_csv('data_2016.csv')
dt_3.to_csv('data_2017.csv')
dt_4.to_csv('data_2018.csv')
dt_5.to_csv('data_2019.csv')

# %%
dt_3
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
dt_2.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
dt_1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
dt_4.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
dt_5.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
dt_1
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      GDP per Capita  Social support  Healthy life expectancy  Freedom  \
# 0           1.39651         1.34951                  0.94143  0.66557
# ...

# %%
dt_1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score', 'GDP per Capita',
#        'Social support', 'Healthy life expectancy', 'Freedom',
#        'Perceptions of corruption', 'Generosity'],
#       dtype='object')

# %%
#dt_1 = dt_1.drop(columns=['Standard Error','Dystopia Residual','Happiness Rank'])

# %%
#dt_1.rename(columns={'Economy (GDP per Capita)': 'GDP per Capita',
                     'Family': 'Social support',
                     'Health (Life Expectancy)': 'Healthy life expectancy',
                     'Trust (Government Corruption)': 'Perceptions of corruption'},
            inplace=True)

# %%
dt_2.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score', 'GDP per Capita',
#        'Social support', 'Healthy life expectancy', 'Freedom',
#        'Perceptions of corruption', 'Generosity'],
#       dtype='object')

# %%
#dt_2 = dt_2.drop(columns=['Lower Confidence Interval','Dystopia Residual','Happiness Rank','Upper Confidence Interval',])

# %%
#dt_2.rename(columns={'Economy (GDP per Capita)': 'GDP per Capita',
                     'Family': 'Social support',
                     'Health (Life Expectancy)': 'Healthy life expectancy',
                     'Trust (Government Corruption)': 'Perceptions of corruption'},
            inplace=True)

# %%
dt_3.columns
# Out:
# Index(['Country', 'Happiness Score', 'GDP per Capita', 'Social support',
#        'Healthy life expectancy', 'Freedom', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#dt_3 = dt_3.drop(columns=['Whisker.high','Dystopia.Residual','Happiness.Rank','Whisker.low',])

# %%
#dt_3.rename(columns={'Economy..GDP.per.Capita.': 'GDP per Capita',
                     'Family': 'Social support',
                     'Health..Life.Expectancy.': 'Healthy life expectancy',
                     'Trust..Government.Corruption.': 'Perceptions of corruption',
                     'Happiness.Score':'Happiness Score'},
            inplace=True)

# %%
dt_4.columns
# Out:
# Index(['Country', 'Happiness Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#dt_4 = dt_4.drop(columns=['Overall rank'])

# %%
#dt_4.rename(columns={'Country or region': 'Country',
                     'Score': 'Happiness Score',
                     'Freedom to make life choices': 'Freedom'
                     },
            inplace=True)

# %%
dt_5.columns
# Out:
# Index(['Country', 'Happiness Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#dt_5 = dt_5.drop(columns=['Overall rank'])

# %%
dt_5.rename(columns={'Country': 'country',
                     'Happiness Score': 'score',
                     'GDP per capita': 'gdp_per_capita',
                     'GDP per capita': 'gdp_per_capita',
                     'Social support': 'social_support',
                     'Healthy life expectancy':'healthy_life_expectancy',
                     'Freedom':'freedom',
                     'Generosity':'generosity'
                     },
            inplace=True)

# %%
dt_1.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
dt_2.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
years = [2015, 2016, 2017, 2018, 2019]
paths = {
    2015: 'data_2015.csv',
    2016: 'data_2016.csv',
    2017: 'data_2017.csv',
    2018: 'data_2018.csv',
    2019: 'data_2019.csv'
}

dfs = []
for y in years:
    df = pd.read_csv(paths[y])
    df['year'] = y
    dfs.append(df)

# %%
# Read one file with 'Region' info (e.g., 2015)
df_2015 = pd.read_csv(paths[2015])
if 'Region' in df_2015.columns:
    region_map = df_2015[['Country', 'Region']].drop_duplicates().set_index('Country')['Region'].to_dict()
else:
    region_map = {}

# If you have 'Region' in 2016/2017, you can expand the mapping:
for year in [2016, 2017]:
    df = pd.read_csv(paths[year])
    if 'Region' in df.columns:
        region_map.update(df[['Country', 'Region']].drop_duplicates().set_index('Country')['Region'].to_dict())

# %%
for df in dfs:
    df['region'] = df['Country'].map(region_map)

# %%
col_rename = {
    'Country': 'country',
    'Happiness Score': 'score',
    'GDP per capita': 'gdp_per_capita',
    'Social support': 'social_support',
    'Healthy life expectancy': 'healthy_life_expectancy',
    'Freedom': 'freedom',
    'Generosity': 'generosity',
    'Perceptions of corruption': 'corruption',
    'region': 'region',
    'year': 'year'
}

for i in range(len(dfs)):
    dfs[i] = dfs[i].rename(columns=col_rename)

# %%
# Concatenate all DataFrames
df_all = pd.concat(dfs, ignore_index=True)

# Optional: Check missing regions
missing_regions = df_all[df_all['region'].isnull()]['country'].unique()
print("Countries missing region info:", missing_regions)

# Export to CSV for MySQL import
df_all.to_csv("happiness_all_years_clean.csv", index=False)
# Out:
# Countries missing region info: ['Taiwan Province of China' 'Hong Kong S.A.R., China' 'Trinidad & Tobago'
#  'Northern Cyprus' 'North Macedonia' 'Gambia']

# %%
# Manually update missing regions
manual_regions = {
    'Taiwan Province of China': 'Eastern Asia',
    'Hong Kong S.A.R., China': 'Eastern Asia',
    'Trinidad & Tobago': 'Latin America and Caribbean',
    'Northern Cyprus': 'Western Asia',
    'North Macedonia': 'Central and Eastern Europe',
    'Gambia': 'Sub-Saharan Africa'
}

# Fill missing regions
df_all['region'] = df_all.apply(
    lambda row: manual_regions.get(row['country'], row['region']),
    axis=1
)

# Optional: Re-check for any missing regions
still_missing = df_all[df_all['region'].isnull()]['country'].unique()
print("Still missing regions:", still_missing)
# Out:
# Still missing regions: []

# %%
df_all.to_csv("happiness_all_years_clean.csv", index=False)

# %%
df_all
# Out:
#      Unnamed: 0                   country          Region  score  \
# 0             0               Switzerland  Western Europe  7.587
# 1             1                   Iceland  Western Europe  7.561
# 2             2                   Denmark  Western Europe  7.527
# 3             3                    Norway  Western Europe  7.522
# 4             4                    Canada   North America  7.427
# ..          ...                       ...             ...    ...
# 777         151                    Rwanda             NaN  3.334
# 778         152                  Tanzania             NaN  3.231
# 779         153               Afghanistan             NaN  3.203
# 780         154  Central African Republic             NaN  3.083
# 781         155               South Sudan             NaN  2.853
#
#      GDP per Capita  social_support  healthy_life_expectancy  freedom  \
# 0           1.39651         1.34951                  0.94143  0.66557
# ...

# %%
df_all['gdp_per_capita'] = df_all['GDP per Capita'].combine_first(df_all['gdp_per_capita'])

# %%
df_all = df_all.drop(['Unnamed: 0'], axis=1)

# %%
columns_order = [
    'country', 'year', 'region', 'score', 'gdp_per_capita', 'social_support',
    'healthy_life_expectancy', 'freedom', 'generosity', 'corruption'
]
df_all = df_all[columns_order]

# %%
df_all
# Out:
#                       country  year              region  score  \
# 0                 Switzerland  2015      Western Europe  7.587
# 1                     Iceland  2015      Western Europe  7.561
# 2                     Denmark  2015      Western Europe  7.527
# 3                      Norway  2015      Western Europe  7.522
# 4                      Canada  2015       North America  7.427
# ..                        ...   ...                 ...    ...
# 777                    Rwanda  2015  Sub-Saharan Africa  3.334
# 778                  Tanzania  2015  Sub-Saharan Africa  3.231
# 779               Afghanistan  2015       Southern Asia  3.203
# 780  Central African Republic  2015  Sub-Saharan Africa  3.083
# 781               South Sudan  2015  Sub-Saharan Africa  2.853
#
#      gdp_per_capita  social_support  healthy_life_expectancy  freedom  \
# 0           1.39651         1.34951                  0.94143  0.66557
# ...

# %%
df_country_id = pd.DataFrame(df_all[['country', 'region']].drop_duplicates().reset_index(drop=True))

df_country_id
# Out:
#                      country                       region
# 0                Switzerland               Western Europe
# 1                    Iceland               Western Europe
# 2                    Denmark               Western Europe
# 3                     Norway               Western Europe
# 4                     Canada                North America
# ..                       ...                          ...
# 165  Hong Kong S.A.R., China                 Eastern Asia
# 166        Trinidad & Tobago  Latin America and Caribbean
# 167          Northern Cyprus                 Western Asia
# 168          North Macedonia   Central and Eastern Europe
# 169                   Gambia           Sub-Saharan Africa
#
# [170 rows x 2 columns]

# %%
df_country_id
# Out:
#                      country                       region
# 0                Switzerland               Western Europe
# 1                    Iceland               Western Europe
# 2                    Denmark               Western Europe
# 3                     Norway               Western Europe
# 4                     Canada                North America
# ..                       ...                          ...
# 165  Hong Kong S.A.R., China                 Eastern Asia
# 166        Trinidad & Tobago  Latin America and Caribbean
# 167          Northern Cyprus                 Western Asia
# 168          North Macedonia   Central and Eastern Europe
# 169                   Gambia           Sub-Saharan Africa
#
# [170 rows x 2 columns]

# %%
df_country_id["country_id"] = range(1, len(df_country_id) + 1)
df_country_id = df_country_id[["country_id", "country",'region']]
df_country_id
# Out:
#      country_id                  country                       region
# 0             1              Switzerland               Western Europe
# 1             2                  Iceland               Western Europe
# 2             3                  Denmark               Western Europe
# 3             4                   Norway               Western Europe
# 4             5                   Canada                North America
# ..          ...                      ...                          ...
# 165         166  Hong Kong S.A.R., China                 Eastern Asia
# 166         167        Trinidad & Tobago  Latin America and Caribbean
# 167         168          Northern Cyprus                 Western Asia
# 168         169          North Macedonia   Central and Eastern Europe
# 169         170                   Gambia           Sub-Saharan Africa
#
# [170 rows x 3 columns]

# %%
countries_with_id = pd.merge(
    df_country_id,
    df_region_id[['region_id', 'region']],
    on='region',
    how='left'
)

# %%
df_country_id = countries_with_id.drop(columns=['region'])
df_country_id
# Out:
#      country_id                  country  region_id
# 0             1              Switzerland          1
# 1             2                  Iceland          1
# 2             3                  Denmark          1
# 3             4                   Norway          1
# 4             5                   Canada          2
# ..          ...                      ...        ...
# 165         166  Hong Kong S.A.R., China          8
# 166         167        Trinidad & Tobago          5
# 167         168          Northern Cyprus         11
# 168         169          North Macedonia          7
# 169         170                   Gambia          9
#
# [170 rows x 3 columns]

# %%
columns_orde = [
    'country_id', 'region_id', 'country'
]
df_country_id = df_country_id[columns_orde]
df_country_id
# Out:
#      country_id  region_id                  country
# 0             1          1              Switzerland
# 1             2          1                  Iceland
# 2             3          1                  Denmark
# 3             4          1                   Norway
# 4             5          2                   Canada
# ..          ...        ...                      ...
# 165         166          8  Hong Kong S.A.R., China
# 166         167          5        Trinidad & Tobago
# 167         168         11          Northern Cyprus
# 168         169          7          North Macedonia
# 169         170          9                   Gambia
#
# [170 rows x 3 columns]

# %%
df_country_id.to_csv("country_id.csv", index=False)

# %%
df_region_id = pd.DataFrame(df_all['region'].unique(), columns=["region"])

df_region_id
# Out:
#                              region
# 0                    Western Europe
# 1                     North America
# 2         Australia and New Zealand
# 3   Middle East and Northern Africa
# 4       Latin America and Caribbean
# 5                 Southeastern Asia
# 6        Central and Eastern Europe
# 7                      Eastern Asia
# 8                Sub-Saharan Africa
# 9                     Southern Asia
# 10                     Western Asia

# %%
df_region_id["region_id"] = range(1, len(df_region_id) + 1)
df_region_id = df_region_id[["region_id", "region"]]
df_region_id
# Out:
#     region_id                           region
# 0           1                   Western Europe
# 1           2                    North America
# 2           3        Australia and New Zealand
# 3           4  Middle East and Northern Africa
# 4           5      Latin America and Caribbean
# 5           6                Southeastern Asia
# 6           7       Central and Eastern Europe
# 7           8                     Eastern Asia
# 8           9               Sub-Saharan Africa
# 9          10                    Southern Asia
# 10         11                     Western Asia

# %%
df_region_id.to_csv("df_region_id.csv", index=False)
